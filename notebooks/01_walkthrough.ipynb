# %% [markdown]
# # UniVAD Reproduction — Walkthrough
#
# End-to-end walkthrough of UniVAD inference on a single category.
# Covers component segmentation, patch matching, and anomaly score visualization.
#
# **Paper:** Gu et al., UniVAD: A Training-free Unified Model for Few-shot Visual Anomaly Detection, CVPR 2025

# %%
# Environment check
import torch
print(f'PyTorch: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
